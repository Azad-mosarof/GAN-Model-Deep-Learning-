# %%
# !pip install opendatasets --upgrade --quiet
# !pip install IProgress
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: IProgress in /home/azadm/.local/lib/python3.9/site-packages (0.4)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from IProgress) (1.16.0)

# %%
import opendatasets as od

dataset_url = 'https://www.kaggle.com/splcher/animefacedataset'
od.download(dataset_url)
# Out:
# Downloading animefacedataset.zip to ./animefacedataset
# 100%|██████████| 395M/395M [01:27<00:00, 4.72MB/s]

# %%
import IProgress
import os
import torch

DATA_DIR = './animefacedataset'
print(os.listdir(DATA_DIR))
# Out:
# ['images']

# %%
print(os.listdir(DATA_DIR+'/images')[:10])
# Out:
# ['0_2000.jpg', '10000_2004.jpg', '10001_2004.jpg', '10002_2004.jpg', '10003_2004.jpg', '10004_2004.jpg', '10005_2004.jpg', '10006_2004.jpg', '10007_2004.jpg', '10008_2004.jpg']

# %%
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as T

# %%
image_size = 64
batch_size = 128
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
train_ds = ImageFolder(DATA_DIR, transform=T.Compose([
    T.Resize(image_size),
    T.CenterCrop(image_size),
    T.ToTensor(),
    T.Normalize(*stats)]))

train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)

# %%
import torch
from tqdm.notebook import tqdm
import torch.nn.functional as F
from torchvision.utils import make_grid
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

# %%
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

# %%
show_batch(train_dl)

# %%
# !pip install jovian --upgrade --quiet

# %%
import jovian
project_name = 'anime.ipynb'
jovian.utils.credentials.purge_creds()
jovian.commit(filename=project_name, environment=None)
# Out:
# [jovian] Please enter your API key ( from https://jovian.ai/ ):
# API KEY:

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
import torch.nn as nn

# %%
discriminator = nn.Sequential(
    # in: 3 x 64 x 64

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 32 x 32

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 16 x 16

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 8 x 8

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 4 x 4

    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

# %%
discriminator = to_device(discriminator, device)

# %%
latent_size = 128

# %%
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 8 x 8

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 16 x 16

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 32 x 32

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 64 x 64
)

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([128, 3, 64, 64])

# %%
generator = to_device(generator, device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
from torchvision.utils import save_image

# %%
from torchvision.utils import save_image

# %%
sample_dir = '/home/azadm/vs-code-files/Deep_learning/anime_generation/sample_dir'
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
save_samples(0, fixed_latent)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-images-0000.png

# %%
images_batch_list = []
i = 0

x = tqdm(train_dl)
for imgs,_ in x:
    images_batch_list.append(imgs)
    if(i<10):
        i+=1
    else:
        break
# Out:
#   0%|          | 0/497 [00:00<?, ?it/s]

# %%
len(images_batch_list)
# Out:
# 11

# %%
def fit(epochs, lr, start_idx=1):
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images in images_batch_list:
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.0002
epochs = 25

# %%
history = fit(epochs, lr)
# Out:
# Epoch [1/25], loss_g: 0.2501, loss_d: 1.2444, real_score: 0.4023, fake_score: 0.0212
# Epoch [1/25], loss_g: 0.8437, loss_d: 5.0599, real_score: 0.9752, fake_score: 0.9910
# Epoch [1/25], loss_g: 4.3194, loss_d: 2.8981, real_score: 0.8952, fake_score: 0.9280
# Epoch [1/25], loss_g: 4.4522, loss_d: 1.1288, real_score: 0.5007, fake_score: 0.1850
# Epoch [1/25], loss_g: 2.2971, loss_d: 1.4632, real_score: 0.3843, fake_score: 0.1890
# Epoch [1/25], loss_g: 3.2349, loss_d: 1.7132, real_score: 0.6624, fake_score: 0.6903
# Epoch [1/25], loss_g: 3.5372, loss_d: 1.2468, real_score: 0.5615, fake_score: 0.4003
# Epoch [1/25], loss_g: 2.7325, loss_d: 1.1920, real_score: 0.5453, fake_score: 0.3488
# Epoch [1/25], loss_g: 2.9499, loss_d: 1.3773, real_score: 0.5839, fake_score: 0.4994
# Epoch [1/25], loss_g: 2.8878, loss_d: 1.1750, real_score: 0.5671, fake_score: 0.3844
# Epoch [1/25], loss_g: 2.3558, loss_d: 1.2021, real_score: 0.5247, fake_score: 0.3432
# Epoch [1/25], loss_g: 2.3558, loss_d: 1.2021, real_score: 0.5247, fake_score: 0.3432
# Saving generated-images-0001.png
# Epoch [2/25], loss_g: 2.9248, loss_d: 0.9903, real_score: 0.6861, fake_score: 0.4140
# Epoch [2/25], loss_g: 2.1939, loss_d: 1.0466, real_score: 0.5560, fake_score: 0.2811
# Epoch [2/25], loss_g: 3.2170, loss_d: 1.1326, real_score: 0.6816, fake_score: 0.4787
# Epoch [2/25], loss_g: 1.9561, loss_d: 1.0183, real_score: 0.5402, fake_score: 0.2194
# Epoch [2/25], loss_g: 3.9937, loss_d: 1.1632, real_score: 0.7988, fake_score: 0.5748
# Epoch [2/25], loss_g: 1.8841, loss_d: 1.2448, real_score: 0.3982, fake_score: 0.1463
# Epoch [2/25], loss_g: 3.2467, loss_d: 1.4848, real_score: 0.6714, fake_score: 0.6030
# Epoch [2/25], loss_g: 3.3895, loss_d: 0.9247, real_score: 0.6016, fake_score: 0.2905
# Epoch [2/25], loss_g: 2.8146, loss_d: 0.9545, real_score: 0.5771, fake_score: 0.2879
# Epoch [2/25], loss_g: 5.5799, loss_d: 1.1594, real_score: 0.7367, fake_score: 0.5265
# Epoch [2/25], loss_g: 1.4949, loss_d: 1.4256, real_score: 0.3405, fake_score: 0.0827
# Epoch [2/25], loss_g: 1.4949, loss_d: 1.4256, real_score: 0.3405, fake_score: 0.0827
# Saving generated-images-0002.png
# Epoch [3/25], loss_g: 4.0532, loss_d: 1.8174, real_score: 0.8567, fake_score: 0.7682
# Epoch [3/25], loss_g: 2.8017, loss_d: 1.0828, real_score: 0.4620, fake_score: 0.1709
# Epoch [3/25], loss_g: 2.5144, loss_d: 1.0549, real_score: 0.6305, fake_score: 0.3856
# Epoch [3/25], loss_g: 3.4056, loss_d: 0.9487, real_score: 0.7317, fake_score: 0.4292
# Epoch [3/25], loss_g: 2.9339, loss_d: 0.6707, real_score: 0.6809, fake_score: 0.2200
# Epoch [3/25], loss_g: 3.3819, loss_d: 0.7204, real_score: 0.7466, fake_score: 0.3150
# Epoch [3/25], loss_g: 3.1434, loss_d: 0.8469, real_score: 0.6733, fake_score: 0.2805
# Epoch [3/25], loss_g: 4.7231, loss_d: 0.8075, real_score: 0.7960, fake_score: 0.4019
# Epoch [3/25], loss_g: 1.6293, loss_d: 1.1597, real_score: 0.4436, fake_score: 0.0936
# Epoch [3/25], loss_g: 5.0254, loss_d: 1.7026, real_score: 0.9107, fake_score: 0.7708
# Epoch [3/25], loss_g: 2.9202, loss_d: 1.5952, real_score: 0.2855, fake_score: 0.0494
# Epoch [3/25], loss_g: 2.9202, loss_d: 1.5952, real_score: 0.2855, fake_score: 0.0494
# Saving generated-images-0003.png
# Epoch [4/25], loss_g: 1.8787, loss_d: 0.8040, real_score: 0.7009, fake_score: 0.3172
# Epoch [4/25], loss_g: 3.9039, loss_d: 1.1177, real_score: 0.8615, fake_score: 0.5963
# Epoch [4/25], loss_g: 3.5084, loss_d: 0.6316, real_score: 0.6702, fake_score: 0.1579
# Epoch [4/25], loss_g: 3.5406, loss_d: 0.6890, real_score: 0.7608, fake_score: 0.2809
# Epoch [4/25], loss_g: 5.0329, loss_d: 0.7451, real_score: 0.7940, fake_score: 0.3636
# Epoch [4/25], loss_g: 2.9428, loss_d: 0.7312, real_score: 0.6273, fake_score: 0.1192
# Epoch [4/25], loss_g: 7.1225, loss_d: 1.1512, real_score: 0.8426, fake_score: 0.5888
# Epoch [4/25], loss_g: 3.7910, loss_d: 1.0925, real_score: 0.4628, fake_score: 0.0229
# Epoch [4/25], loss_g: 3.3725, loss_d: 0.7490, real_score: 0.8382, fake_score: 0.3915
# Epoch [4/25], loss_g: 4.1523, loss_d: 0.6437, real_score: 0.8340, fake_score: 0.3425
# Epoch [4/25], loss_g: 3.1655, loss_d: 0.5434, real_score: 0.7271, fake_score: 0.1600
# Epoch [4/25], loss_g: 3.1655, loss_d: 0.5434, real_score: 0.7271, fake_score: 0.1600
# Saving generated-images-0004.png
# Epoch [5/25], loss_g: 4.3803, loss_d: 0.8314, real_score: 0.8232, fake_score: 0.4342
# Epoch [5/25], loss_g: 2.9132, loss_d: 0.7328, real_score: 0.6121, fake_score: 0.1267
# Epoch [5/25], loss_g: 5.8883, loss_d: 1.1002, real_score: 0.8109, fake_score: 0.5564
# Epoch [5/25], loss_g: 2.7021, loss_d: 1.1508, real_score: 0.4053, fake_score: 0.0425
# Epoch [5/25], loss_g: 7.1410, loss_d: 1.2365, real_score: 0.9276, fake_score: 0.6614
# Epoch [5/25], loss_g: 3.4781, loss_d: 1.1812, real_score: 0.3690, fake_score: 0.0161
# Epoch [5/25], loss_g: 3.0223, loss_d: 0.7613, real_score: 0.8071, fake_score: 0.3760
# Epoch [5/25], loss_g: 5.0371, loss_d: 0.7361, real_score: 0.8600, fake_score: 0.4157
# Epoch [5/25], loss_g: 2.9377, loss_d: 0.9449, real_score: 0.4846, fake_score: 0.0820
# Epoch [5/25], loss_g: 5.4608, loss_d: 1.1770, real_score: 0.8153, fake_score: 0.5471
# Epoch [5/25], loss_g: 3.3130, loss_d: 0.9971, real_score: 0.5109, fake_score: 0.0799
# Epoch [5/25], loss_g: 3.3130, loss_d: 0.9971, real_score: 0.5109, fake_score: 0.0799
# Saving generated-images-0005.png
# Epoch [6/25], loss_g: 5.1016, loss_d: 1.0700, real_score: 0.7576, fake_score: 0.4493
# Epoch [6/25], loss_g: 3.0799, loss_d: 0.8121, real_score: 0.5949, fake_score: 0.1235
# Epoch [6/25], loss_g: 5.1020, loss_d: 0.7705, real_score: 0.8644, fake_score: 0.4187
# Epoch [6/25], loss_g: 3.5637, loss_d: 0.6063, real_score: 0.7035, fake_score: 0.1083
# Epoch [6/25], loss_g: 3.6937, loss_d: 0.7012, real_score: 0.8154, fake_score: 0.3404
# Epoch [6/25], loss_g: 3.6470, loss_d: 0.5944, real_score: 0.7826, fake_score: 0.2405
# Epoch [6/25], loss_g: 2.7909, loss_d: 0.6985, real_score: 0.7364, fake_score: 0.2177
# Epoch [6/25], loss_g: 3.8085, loss_d: 0.7379, real_score: 0.8395, fake_score: 0.3595
# Epoch [6/25], loss_g: 2.4487, loss_d: 0.7254, real_score: 0.6585, fake_score: 0.1926
# Epoch [6/25], loss_g: 4.2107, loss_d: 0.7920, real_score: 0.8366, fake_score: 0.4273
# Epoch [6/25], loss_g: 2.4730, loss_d: 0.7983, real_score: 0.5834, fake_score: 0.1216
# Epoch [6/25], loss_g: 2.4730, loss_d: 0.7983, real_score: 0.5834, fake_score: 0.1216
# Saving generated-images-0006.png
# Epoch [7/25], loss_g: 6.2061, loss_d: 1.1986, real_score: 0.8548, fake_score: 0.5971
# Epoch [7/25], loss_g: 3.1763, loss_d: 1.2746, real_score: 0.3710, fake_score: 0.0195
# Epoch [7/25], loss_g: 3.1286, loss_d: 0.6234, real_score: 0.8413, fake_score: 0.3178
# Epoch [7/25], loss_g: 7.3588, loss_d: 0.9995, real_score: 0.8506, fake_score: 0.5079
# Epoch [7/25], loss_g: 4.1031, loss_d: 1.0204, real_score: 0.4589, fake_score: 0.0121
# Epoch [7/25], loss_g: 3.8244, loss_d: 0.7272, real_score: 0.8141, fake_score: 0.3439
# Epoch [7/25], loss_g: 6.0532, loss_d: 0.8548, real_score: 0.7879, fake_score: 0.4000
# Epoch [7/25], loss_g: 2.6776, loss_d: 0.8956, real_score: 0.5315, fake_score: 0.0745
# Epoch [7/25], loss_g: 6.9922, loss_d: 1.6648, real_score: 0.7649, fake_score: 0.7071
# Epoch [7/25], loss_g: 2.7863, loss_d: 1.3259, real_score: 0.3495, fake_score: 0.0216
# Epoch [7/25], loss_g: 5.9491, loss_d: 1.3581, real_score: 0.8836, fake_score: 0.6483
# Epoch [7/25], loss_g: 5.9491, loss_d: 1.3581, real_score: 0.8836, fake_score: 0.6483
# Saving generated-images-0007.png
# Epoch [8/25], loss_g: 3.8522, loss_d: 0.9107, real_score: 0.5232, fake_score: 0.0501
# Epoch [8/25], loss_g: 3.7542, loss_d: 0.7717, real_score: 0.8219, fake_score: 0.3647
# Epoch [8/25], loss_g: 5.3312, loss_d: 0.7703, real_score: 0.7805, fake_score: 0.3568
# Epoch [8/25], loss_g: 2.2499, loss_d: 0.9244, real_score: 0.5419, fake_score: 0.1287
# Epoch [8/25], loss_g: 6.0932, loss_d: 1.3662, real_score: 0.9206, fake_score: 0.6618
# Epoch [8/25], loss_g: 3.1277, loss_d: 1.2611, real_score: 0.3857, fake_score: 0.0219
# Epoch [8/25], loss_g: 2.4775, loss_d: 0.6128, real_score: 0.8486, fake_score: 0.2961
# Epoch [8/25], loss_g: 4.8283, loss_d: 0.8374, real_score: 0.9090, fake_score: 0.4900
# Epoch [8/25], loss_g: 3.3881, loss_d: 0.7566, real_score: 0.5808, fake_score: 0.0512
# Epoch [8/25], loss_g: 2.4856, loss_d: 0.5143, real_score: 0.7813, fake_score: 0.1763
# Epoch [8/25], loss_g: 4.1523, loss_d: 0.8080, real_score: 0.8535, fake_score: 0.4409
# Epoch [8/25], loss_g: 4.1523, loss_d: 0.8080, real_score: 0.8535, fake_score: 0.4409
# Saving generated-images-0008.png
# Epoch [9/25], loss_g: 3.1169, loss_d: 0.5708, real_score: 0.6752, fake_score: 0.0959
# Epoch [9/25], loss_g: 2.5714, loss_d: 0.6474, real_score: 0.7513, fake_score: 0.2419
# Epoch [9/25], loss_g: 4.5106, loss_d: 0.7808, real_score: 0.8380, fake_score: 0.4151
# Epoch [9/25], loss_g: 3.0216, loss_d: 0.6623, real_score: 0.6292, fake_score: 0.1072
# Epoch [9/25], loss_g: 3.8727, loss_d: 0.6937, real_score: 0.8236, fake_score: 0.3627
# Epoch [9/25], loss_g: 3.8672, loss_d: 0.7341, real_score: 0.6911, fake_score: 0.2441
# Epoch [9/25], loss_g: 3.9198, loss_d: 0.7878, real_score: 0.7213, fake_score: 0.3042
# Epoch [9/25], loss_g: 3.5934, loss_d: 0.6424, real_score: 0.7206, fake_score: 0.2033
# Epoch [9/25], loss_g: 7.6383, loss_d: 1.1410, real_score: 0.7709, fake_score: 0.5292
# Epoch [9/25], loss_g: 2.1666, loss_d: 1.4138, real_score: 0.3385, fake_score: 0.0224
# Epoch [9/25], loss_g: 5.9038, loss_d: 1.0311, real_score: 0.9449, fake_score: 0.5903
# Epoch [9/25], loss_g: 5.9038, loss_d: 1.0311, real_score: 0.9449, fake_score: 0.5903
# Saving generated-images-0009.png
# Epoch [10/25], loss_g: 4.7187, loss_d: 0.4563, real_score: 0.6859, fake_score: 0.0300
# Epoch [10/25], loss_g: 2.9874, loss_d: 0.2818, real_score: 0.8490, fake_score: 0.0902
# Epoch [10/25], loss_g: 5.2567, loss_d: 0.7305, real_score: 0.9041, fake_score: 0.4391
# Epoch [10/25], loss_g: 4.0706, loss_d: 0.4384, real_score: 0.7204, fake_score: 0.0480
# Epoch [10/25], loss_g: 4.2798, loss_d: 0.3537, real_score: 0.9001, fake_score: 0.2080
# Epoch [10/25], loss_g: 4.4748, loss_d: 0.4657, real_score: 0.8015, fake_score: 0.1815
# Epoch [10/25], loss_g: 3.9438, loss_d: 0.5333, real_score: 0.7474, fake_score: 0.1706
# Epoch [10/25], loss_g: 5.2354, loss_d: 0.3601, real_score: 0.8641, fake_score: 0.1755
# Epoch [10/25], loss_g: 2.7134, loss_d: 0.4173, real_score: 0.7419, fake_score: 0.0658
# Epoch [10/25], loss_g: 9.7058, loss_d: 1.0440, real_score: 0.9404, fake_score: 0.5717
# Epoch [10/25], loss_g: 3.7794, loss_d: 2.8932, real_score: 0.1327, fake_score: 0.0018
# Epoch [10/25], loss_g: 3.7794, loss_d: 2.8932, real_score: 0.1327, fake_score: 0.0018
# Saving generated-images-0010.png
# Epoch [11/25], loss_g: 2.4555, loss_d: 0.5240, real_score: 0.9115, fake_score: 0.3067
# Epoch [11/25], loss_g: 6.3894, loss_d: 1.1412, real_score: 0.9721, fake_score: 0.6274
# Epoch [11/25], loss_g: 5.2136, loss_d: 0.8123, real_score: 0.5312, fake_score: 0.0143
# Epoch [11/25], loss_g: 3.2693, loss_d: 0.2789, real_score: 0.8315, fake_score: 0.0579
# Epoch [11/25], loss_g: 4.3475, loss_d: 0.6550, real_score: 0.9471, fake_score: 0.4115
# Epoch [11/25], loss_g: 3.9680, loss_d: 0.4001, real_score: 0.7944, fake_score: 0.1294
# Epoch [11/25], loss_g: 3.5892, loss_d: 0.4761, real_score: 0.8081, fake_score: 0.2039
# Epoch [11/25], loss_g: 3.2007, loss_d: 0.4194, real_score: 0.8375, fake_score: 0.1900
# Epoch [11/25], loss_g: 4.9179, loss_d: 0.6340, real_score: 0.8424, fake_score: 0.3349
# Epoch [11/25], loss_g: 3.2508, loss_d: 0.5722, real_score: 0.6657, fake_score: 0.0886
# Epoch [11/25], loss_g: 4.8522, loss_d: 0.8720, real_score: 0.8390, fake_score: 0.4391
# Epoch [11/25], loss_g: 4.8522, loss_d: 0.8720, real_score: 0.8390, fake_score: 0.4391
# Saving generated-images-0011.png
# Epoch [12/25], loss_g: 2.2129, loss_d: 0.8418, real_score: 0.5353, fake_score: 0.0837
# Epoch [12/25], loss_g: 5.2741, loss_d: 1.1194, real_score: 0.8944, fake_score: 0.5946
# Epoch [12/25], loss_g: 3.1706, loss_d: 0.8221, real_score: 0.5195, fake_score: 0.0522
# Epoch [12/25], loss_g: 3.8655, loss_d: 0.7234, real_score: 0.8515, fake_score: 0.3813
# Epoch [12/25], loss_g: 4.0241, loss_d: 0.5418, real_score: 0.7596, fake_score: 0.1917
# Epoch [12/25], loss_g: 4.1198, loss_d: 0.6664, real_score: 0.7330, fake_score: 0.2457
# Epoch [12/25], loss_g: 3.3221, loss_d: 0.6618, real_score: 0.7096, fake_score: 0.1976
# Epoch [12/25], loss_g: 6.5856, loss_d: 0.9604, real_score: 0.7727, fake_score: 0.4417
# Epoch [12/25], loss_g: 1.6986, loss_d: 1.4026, real_score: 0.3358, fake_score: 0.0176
# Epoch [12/25], loss_g: 5.7788, loss_d: 1.3480, real_score: 0.9499, fake_score: 0.6453
# Epoch [12/25], loss_g: 3.8995, loss_d: 0.8217, real_score: 0.5157, fake_score: 0.0324
# Epoch [12/25], loss_g: 3.8995, loss_d: 0.8217, real_score: 0.5157, fake_score: 0.0324
# Saving generated-images-0012.png
# Epoch [13/25], loss_g: 2.0091, loss_d: 0.5754, real_score: 0.7284, fake_score: 0.1708
# Epoch [13/25], loss_g: 5.0856, loss_d: 1.1262, real_score: 0.9270, fake_score: 0.6045
# Epoch [13/25], loss_g: 3.9294, loss_d: 0.7886, real_score: 0.5497, fake_score: 0.0443
# Epoch [13/25], loss_g: 2.4020, loss_d: 0.4573, real_score: 0.7768, fake_score: 0.1531
# Epoch [13/25], loss_g: 4.9428, loss_d: 0.8003, real_score: 0.9165, fake_score: 0.4660
# Epoch [13/25], loss_g: 3.8777, loss_d: 0.5298, real_score: 0.6674, fake_score: 0.0587
# Epoch [13/25], loss_g: 2.7762, loss_d: 0.4283, real_score: 0.8222, fake_score: 0.1743
# Epoch [13/25], loss_g: 4.9607, loss_d: 0.6870, real_score: 0.8991, fake_score: 0.4102
# Epoch [13/25], loss_g: 2.8009, loss_d: 0.8070, real_score: 0.5591, fake_score: 0.0783
# Epoch [13/25], loss_g: 4.6566, loss_d: 0.7610, real_score: 0.8761, fake_score: 0.4244
# Epoch [13/25], loss_g: 3.5989, loss_d: 0.5903, real_score: 0.6783, fake_score: 0.1151
# Epoch [13/25], loss_g: 3.5989, loss_d: 0.5903, real_score: 0.6783, fake_score: 0.1151
# Saving generated-images-0013.png
# Epoch [14/25], loss_g: 3.8475, loss_d: 0.6168, real_score: 0.7978, fake_score: 0.2869
# Epoch [14/25], loss_g: 3.9913, loss_d: 0.6602, real_score: 0.7439, fake_score: 0.2540
# Epoch [14/25], loss_g: 3.6942, loss_d: 0.6287, real_score: 0.7333, fake_score: 0.2210
# Epoch [14/25], loss_g: 3.3832, loss_d: 0.6187, real_score: 0.7299, fake_score: 0.2238
# Epoch [14/25], loss_g: 4.9698, loss_d: 0.6493, real_score: 0.8294, fake_score: 0.3392
# Epoch [14/25], loss_g: 2.1774, loss_d: 0.6781, real_score: 0.5952, fake_score: 0.0628
# Epoch [14/25], loss_g: 5.7548, loss_d: 0.9233, real_score: 0.9257, fake_score: 0.5440
# Epoch [14/25], loss_g: 2.8944, loss_d: 0.8814, real_score: 0.4823, fake_score: 0.0327
# Epoch [14/25], loss_g: 3.3399, loss_d: 0.7059, real_score: 0.8465, fake_score: 0.3771
# Epoch [14/25], loss_g: 4.2240, loss_d: 0.5479, real_score: 0.8252, fake_score: 0.2644
# Epoch [14/25], loss_g: 3.3269, loss_d: 0.4416, real_score: 0.7804, fake_score: 0.1480
# Epoch [14/25], loss_g: 3.3269, loss_d: 0.4416, real_score: 0.7804, fake_score: 0.1480
# Saving generated-images-0014.png
# Epoch [15/25], loss_g: 3.9620, loss_d: 0.5738, real_score: 0.8112, fake_score: 0.2772
# Epoch [15/25], loss_g: 2.7324, loss_d: 0.4471, real_score: 0.7579, fake_score: 0.1218
# Epoch [15/25], loss_g: 4.4617, loss_d: 0.3922, real_score: 0.9078, fake_score: 0.2411
# Epoch [15/25], loss_g: 3.6825, loss_d: 0.4138, real_score: 0.8029, fake_score: 0.1477
# Epoch [15/25], loss_g: 3.7134, loss_d: 0.4442, real_score: 0.8322, fake_score: 0.2033
# Epoch [15/25], loss_g: 3.9614, loss_d: 0.4523, real_score: 0.8232, fake_score: 0.1931
# Epoch [15/25], loss_g: 3.5293, loss_d: 0.5203, real_score: 0.7737, fake_score: 0.1988
# Epoch [15/25], loss_g: 4.0217, loss_d: 0.5274, real_score: 0.7994, fake_score: 0.2203
# Epoch [15/25], loss_g: 4.8045, loss_d: 0.5062, real_score: 0.8050, fake_score: 0.2133
# Epoch [15/25], loss_g: 4.3380, loss_d: 0.4297, real_score: 0.8178, fake_score: 0.1705
# Epoch [15/25], loss_g: 6.3823, loss_d: 0.6819, real_score: 0.8032, fake_score: 0.3173
# Epoch [15/25], loss_g: 6.3823, loss_d: 0.6819, real_score: 0.8032, fake_score: 0.3173
# Saving generated-images-0015.png
# Epoch [16/25], loss_g: 0.6345, loss_d: 0.9756, real_score: 0.4860, fake_score: 0.0592
# Epoch [16/25], loss_g: 7.4487, loss_d: 1.9744, real_score: 0.9851, fake_score: 0.8194
# Epoch [16/25], loss_g: 5.8013, loss_d: 1.0237, real_score: 0.4412, fake_score: 0.0080
# Epoch [16/25], loss_g: 2.6492, loss_d: 0.4403, real_score: 0.7430, fake_score: 0.0663
# Epoch [16/25], loss_g: 4.9723, loss_d: 1.2133, real_score: 0.9648, fake_score: 0.5959
# Epoch [16/25], loss_g: 4.5253, loss_d: 0.4680, real_score: 0.7564, fake_score: 0.1184
# Epoch [16/25], loss_g: 2.9379, loss_d: 0.6839, real_score: 0.6772, fake_score: 0.1844
# Epoch [16/25], loss_g: 6.7017, loss_d: 1.0636, real_score: 0.8257, fake_score: 0.5252
# Epoch [16/25], loss_g: 3.5893, loss_d: 1.1427, real_score: 0.4070, fake_score: 0.0158
# Epoch [16/25], loss_g: 4.6264, loss_d: 0.6077, real_score: 0.9101, fake_score: 0.3722
# Epoch [16/25], loss_g: 5.3000, loss_d: 0.5439, real_score: 0.8069, fake_score: 0.2380
# Epoch [16/25], loss_g: 5.3000, loss_d: 0.5439, real_score: 0.8069, fake_score: 0.2380
# Saving generated-images-0016.png
# Epoch [17/25], loss_g: 4.2361, loss_d: 0.4896, real_score: 0.7654, fake_score: 0.1482
# Epoch [17/25], loss_g: 7.0441, loss_d: 0.8368, real_score: 0.7714, fake_score: 0.3820
# Epoch [17/25], loss_g: 2.4725, loss_d: 0.9346, real_score: 0.4906, fake_score: 0.0330
# Epoch [17/25], loss_g: 9.7062, loss_d: 1.6025, real_score: 0.9591, fake_score: 0.7402
# Epoch [17/25], loss_g: 4.9741, loss_d: 1.7091, real_score: 0.2432, fake_score: 0.0031
# Epoch [17/25], loss_g: 2.7355, loss_d: 0.3974, real_score: 0.9281, fake_score: 0.2304
# Epoch [17/25], loss_g: 5.8364, loss_d: 0.9368, real_score: 0.9572, fake_score: 0.5419
# Epoch [17/25], loss_g: 4.3809, loss_d: 0.6894, real_score: 0.5892, fake_score: 0.0283
# Epoch [17/25], loss_g: 2.5135, loss_d: 0.3950, real_score: 0.8100, fake_score: 0.1412
# Epoch [17/25], loss_g: 6.1328, loss_d: 0.9156, real_score: 0.9029, fake_score: 0.5037
# Epoch [17/25], loss_g: 3.5663, loss_d: 0.9978, real_score: 0.4390, fake_score: 0.0228
# Epoch [17/25], loss_g: 3.5663, loss_d: 0.9978, real_score: 0.4390, fake_score: 0.0228
# Saving generated-images-0017.png
# Epoch [18/25], loss_g: 3.2456, loss_d: 0.4444, real_score: 0.8829, fake_score: 0.2465
# Epoch [18/25], loss_g: 6.3148, loss_d: 0.6037, real_score: 0.9182, fake_score: 0.3743
# Epoch [18/25], loss_g: 3.3118, loss_d: 0.7776, real_score: 0.5453, fake_score: 0.0380
# Epoch [18/25], loss_g: 4.5406, loss_d: 0.6990, real_score: 0.9086, fake_score: 0.4128
# Epoch [18/25], loss_g: 4.1091, loss_d: 0.5794, real_score: 0.7229, fake_score: 0.1691
# Epoch [18/25], loss_g: 2.9600, loss_d: 0.7557, real_score: 0.6979, fake_score: 0.2541
# Epoch [18/25], loss_g: 6.2386, loss_d: 1.0377, real_score: 0.7971, fake_score: 0.5028
# Epoch [18/25], loss_g: 2.0698, loss_d: 1.1868, real_score: 0.3951, fake_score: 0.0378
# Epoch [18/25], loss_g: 5.5938, loss_d: 1.1781, real_score: 0.9162, fake_score: 0.6114
# Epoch [18/25], loss_g: 4.1423, loss_d: 0.7130, real_score: 0.6066, fake_score: 0.0566
# Epoch [18/25], loss_g: 2.8867, loss_d: 0.4418, real_score: 0.8327, fake_score: 0.1978
# Epoch [18/25], loss_g: 2.8867, loss_d: 0.4418, real_score: 0.8327, fake_score: 0.1978
# Saving generated-images-0018.png
# Epoch [19/25], loss_g: 5.2189, loss_d: 0.6991, real_score: 0.9071, fake_score: 0.4225
# Epoch [19/25], loss_g: 3.4217, loss_d: 0.5901, real_score: 0.6320, fake_score: 0.0519
# Epoch [19/25], loss_g: 3.0584, loss_d: 0.5562, real_score: 0.8050, fake_score: 0.2618
# Epoch [19/25], loss_g: 4.6500, loss_d: 0.5842, real_score: 0.8648, fake_score: 0.3330
# Epoch [19/25], loss_g: 3.1475, loss_d: 0.4986, real_score: 0.6965, fake_score: 0.0801
# Epoch [19/25], loss_g: 3.5478, loss_d: 0.5201, real_score: 0.8507, fake_score: 0.2715
# Epoch [19/25], loss_g: 3.9329, loss_d: 0.4770, real_score: 0.8017, fake_score: 0.2006
# Epoch [19/25], loss_g: 3.0837, loss_d: 0.4407, real_score: 0.7831, fake_score: 0.1492
# Epoch [19/25], loss_g: 3.2323, loss_d: 0.4639, real_score: 0.8287, fake_score: 0.2079
# Epoch [19/25], loss_g: 4.4869, loss_d: 0.4083, real_score: 0.8827, fake_score: 0.2290
# Epoch [19/25], loss_g: 1.8366, loss_d: 0.5623, real_score: 0.6731, fake_score: 0.0846
# Epoch [19/25], loss_g: 1.8366, loss_d: 0.5623, real_score: 0.6731, fake_score: 0.0846
# Saving generated-images-0019.png
# Epoch [20/25], loss_g: 7.8522, loss_d: 1.1008, real_score: 0.9519, fake_score: 0.6106
# Epoch [20/25], loss_g: 2.8263, loss_d: 2.0209, real_score: 0.2090, fake_score: 0.0083
# Epoch [20/25], loss_g: 4.0437, loss_d: 0.6684, real_score: 0.9255, fake_score: 0.4162
# Epoch [20/25], loss_g: 4.8031, loss_d: 0.3403, real_score: 0.9183, fake_score: 0.2084
# Epoch [20/25], loss_g: 3.7819, loss_d: 0.3734, real_score: 0.8073, fake_score: 0.1165
# Epoch [20/25], loss_g: 4.7720, loss_d: 0.5360, real_score: 0.8731, fake_score: 0.3037
# Epoch [20/25], loss_g: 3.5405, loss_d: 0.6532, real_score: 0.6743, fake_score: 0.1733
# Epoch [20/25], loss_g: 5.8694, loss_d: 0.7711, real_score: 0.8078, fake_score: 0.3815
# Epoch [20/25], loss_g: 2.7597, loss_d: 0.7560, real_score: 0.5482, fake_score: 0.0584
# Epoch [20/25], loss_g: 7.0174, loss_d: 0.9326, real_score: 0.9432, fake_score: 0.5450
# Epoch [20/25], loss_g: 5.0674, loss_d: 0.6784, real_score: 0.5702, fake_score: 0.0209
# Epoch [20/25], loss_g: 5.0674, loss_d: 0.6784, real_score: 0.5702, fake_score: 0.0209
# Saving generated-images-0020.png
# Epoch [21/25], loss_g: 2.8973, loss_d: 0.3670, real_score: 0.8501, fake_score: 0.1481
# Epoch [21/25], loss_g: 7.3243, loss_d: 1.1666, real_score: 0.9375, fake_score: 0.6082
# Epoch [21/25], loss_g: 3.8048, loss_d: 1.1013, real_score: 0.4105, fake_score: 0.0187
# Epoch [21/25], loss_g: 3.9748, loss_d: 0.7068, real_score: 0.8449, fake_score: 0.3718
# Epoch [21/25], loss_g: 5.8946, loss_d: 0.6968, real_score: 0.8567, fake_score: 0.3733
# Epoch [21/25], loss_g: 2.7773, loss_d: 0.7638, real_score: 0.5702, fake_score: 0.0539
# Epoch [21/25], loss_g: 6.4073, loss_d: 0.9566, real_score: 0.8918, fake_score: 0.5168
# Epoch [21/25], loss_g: 3.8530, loss_d: 0.6485, real_score: 0.6209, fake_score: 0.0353
# Epoch [21/25], loss_g: 4.4248, loss_d: 0.5731, real_score: 0.8717, fake_score: 0.3110
# Epoch [21/25], loss_g: 4.8525, loss_d: 0.5680, real_score: 0.8009, fake_score: 0.2350
# Epoch [21/25], loss_g: 2.9193, loss_d: 0.6418, real_score: 0.6776, fake_score: 0.1468
# Epoch [21/25], loss_g: 2.9193, loss_d: 0.6418, real_score: 0.6776, fake_score: 0.1468
# Saving generated-images-0021.png
# Epoch [22/25], loss_g: 6.5979, loss_d: 0.8810, real_score: 0.8343, fake_score: 0.4540
# Epoch [22/25], loss_g: 3.3218, loss_d: 0.8158, real_score: 0.5416, fake_score: 0.0289
# Epoch [22/25], loss_g: 6.0841, loss_d: 0.7789, real_score: 0.9181, fake_score: 0.4410
# Epoch [22/25], loss_g: 4.2239, loss_d: 0.4592, real_score: 0.7235, fake_score: 0.0466
# Epoch [22/25], loss_g: 5.3146, loss_d: 0.6277, real_score: 0.8643, fake_score: 0.3413
# Epoch [22/25], loss_g: 2.9336, loss_d: 0.7050, real_score: 0.6617, fake_score: 0.1270
# Epoch [22/25], loss_g: 6.4007, loss_d: 1.0003, real_score: 0.8333, fake_score: 0.5081
# Epoch [22/25], loss_g: 2.2016, loss_d: 1.1224, real_score: 0.4087, fake_score: 0.0282
# Epoch [22/25], loss_g: 6.6143, loss_d: 1.1988, real_score: 0.9169, fake_score: 0.6267
# Epoch [22/25], loss_g: 4.8105, loss_d: 0.7232, real_score: 0.5433, fake_score: 0.0152
# Epoch [22/25], loss_g: 3.0130, loss_d: 0.2265, real_score: 0.8924, fake_score: 0.0915
# Epoch [22/25], loss_g: 3.0130, loss_d: 0.2265, real_score: 0.8924, fake_score: 0.0915
# Saving generated-images-0022.png
# Epoch [23/25], loss_g: 6.1120, loss_d: 0.7885, real_score: 0.9582, fake_score: 0.4771
# Epoch [23/25], loss_g: 4.2465, loss_d: 0.5246, real_score: 0.6727, fake_score: 0.0433
# Epoch [23/25], loss_g: 3.2472, loss_d: 0.5649, real_score: 0.7771, fake_score: 0.2087
# Epoch [23/25], loss_g: 5.0755, loss_d: 0.5826, real_score: 0.8657, fake_score: 0.3296
# Epoch [23/25], loss_g: 3.1872, loss_d: 0.5813, real_score: 0.6610, fake_score: 0.0729
# Epoch [23/25], loss_g: 6.2582, loss_d: 0.6975, real_score: 0.9074, fake_score: 0.4231
# Epoch [23/25], loss_g: 3.2522, loss_d: 0.7444, real_score: 0.5514, fake_score: 0.0267
# Epoch [23/25], loss_g: 7.0415, loss_d: 0.7566, real_score: 0.9343, fake_score: 0.4579
# Epoch [23/25], loss_g: 4.1446, loss_d: 0.6583, real_score: 0.6041, fake_score: 0.0247
# Epoch [23/25], loss_g: 4.5139, loss_d: 0.4820, real_score: 0.9033, fake_score: 0.2849
# Epoch [23/25], loss_g: 4.7955, loss_d: 0.4322, real_score: 0.8428, fake_score: 0.1980
# Epoch [23/25], loss_g: 4.7955, loss_d: 0.4322, real_score: 0.8428, fake_score: 0.1980
# Saving generated-images-0023.png
# Epoch [24/25], loss_g: 4.3013, loss_d: 0.4564, real_score: 0.8031, fake_score: 0.1698
# Epoch [24/25], loss_g: 4.7705, loss_d: 0.5227, real_score: 0.8314, fake_score: 0.2518
# Epoch [24/25], loss_g: 3.3698, loss_d: 0.6226, real_score: 0.7068, fake_score: 0.1728
# Epoch [24/25], loss_g: 7.3059, loss_d: 0.7410, real_score: 0.8819, fake_score: 0.4253
# Epoch [24/25], loss_g: 3.1716, loss_d: 0.8480, real_score: 0.5137, fake_score: 0.0150
# Epoch [24/25], loss_g: 5.1338, loss_d: 0.5697, real_score: 0.9653, fake_score: 0.3953
# Epoch [24/25], loss_g: 4.7955, loss_d: 0.2464, real_score: 0.8588, fake_score: 0.0739
# Epoch [24/25], loss_g: 4.1044, loss_d: 0.2736, real_score: 0.8826, fake_score: 0.1244
# Epoch [24/25], loss_g: 4.2910, loss_d: 0.5171, real_score: 0.8226, fake_score: 0.2268
# Epoch [24/25], loss_g: 4.0043, loss_d: 0.5049, real_score: 0.7678, fake_score: 0.1687
# Epoch [24/25], loss_g: 5.1963, loss_d: 0.5800, real_score: 0.7697, fake_score: 0.2152
# Epoch [24/25], loss_g: 5.1963, loss_d: 0.5800, real_score: 0.7697, fake_score: 0.2152
# Saving generated-images-0024.png
# Epoch [25/25], loss_g: 5.0429, loss_d: 0.4097, real_score: 0.8091, fake_score: 0.1453
# Epoch [25/25], loss_g: 5.0270, loss_d: 0.3901, real_score: 0.8264, fake_score: 0.1439
# Epoch [25/25], loss_g: 4.6651, loss_d: 0.4627, real_score: 0.8000, fake_score: 0.1612
# Epoch [25/25], loss_g: 5.5341, loss_d: 0.2811, real_score: 0.8934, fake_score: 0.1373
# Epoch [25/25], loss_g: 5.5156, loss_d: 0.3811, real_score: 0.8636, fake_score: 0.1832
# Epoch [25/25], loss_g: 2.9621, loss_d: 0.5447, real_score: 0.7420, fake_score: 0.1288
# Epoch [25/25], loss_g: 9.0318, loss_d: 1.0322, real_score: 0.9108, fake_score: 0.5454
# Epoch [25/25], loss_g: 2.8978, loss_d: 2.7912, real_score: 0.1051, fake_score: 0.0014
# Epoch [25/25], loss_g: 4.4834, loss_d: 0.7304, real_score: 0.9444, fake_score: 0.4441
# Epoch [25/25], loss_g: 4.7479, loss_d: 0.2561, real_score: 0.8989, fake_score: 0.1260
# Epoch [25/25], loss_g: 3.8148, loss_d: 0.2973, real_score: 0.8570, fake_score: 0.1122
# Epoch [25/25], loss_g: 3.8148, loss_d: 0.2973, real_score: 0.8570, fake_score: 0.1122
# Saving generated-images-0025.png

# %%
losses_g, losses_d, real_scores, fake_scores = history

# %%
# Save the model checkpoints 
torch.save(generator.state_dict(), 'G.pth')
torch.save(discriminator.state_dict(), 'D.pth')

# %%
from IPython.display import Image

# %%
Image('./generated/generated-images-0001.png')
